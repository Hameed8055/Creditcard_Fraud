# %%
#Important_Libraries

# %%
import numpy as pd 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Loading_File

# %%
df=pd.read_csv("C:\\Users\\M.KAMRAN\\Desktop\\DATA SCIENCE PROJECTS\\creditcard\\creditcard.csv")
print(df.head())
print(df.info())
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#Check_Missing_Values

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#Input_Missing_Values_By_Mean

# %%
#Normalize_/Standarized_Numerical_Features

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
#To understand the class imbalance

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Class', data=df)
plt.title("Class Distribution: Fraud (1) vs Non-Fraud (0)")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

# %%
# Transaction Amount by Class

# %%
print(df.columns.tolist())
# Out:
# ['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Class', 'Amount_scaled', 'Time_scaled']

# %%
# Save the updated DataFrame
df.to_csv("C:\\Users\\M.KAMRAN\\Desktop\\DATA SCIENCE PROJECTS\\creditcard\\creditcard_scaled.csv", index=False)

# %%
# sns.violinplot(x='Class', y='Amount_scaled', data=df)
# sns.stripplot(x='Class', y='Amount_scaled', data=df, jitter=True, alpha=0.3)
# plt.title("Transaction Amount by Class")
# plt.show()
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
df[df['Class'] == 0]['Amount_scaled'].hist(alpha=0.6, bins=50, label='Non-Fraud')
df[df['Class'] == 1]['Amount_scaled'].hist(alpha=0.6, bins=50, label='Fraud', color='red')
plt.legend()
plt.title("Histogram: Amount Scaled by Class")
plt.xlabel("Amount_scaled")
plt.ylabel("Frequency")
plt.show()

# %%
#Transactions Over Time

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Time_scaled', hue='Class', bins=100, element='step', stat='density', common_norm=False)
plt.title("Transaction Time Distribution by Class")
plt.xlabel("Time (Scaled)")
plt.ylabel("Density")
plt.show()

# %%
#Correlation Heatmap

# %%
plt.figure(figsize=(18, 14))
sns.heatmap(df.corr(), cmap='coolwarm', annot=False)
plt.title("Correlation Matrix")
plt.show()

# %%
#reduce dimensions to visualize fraud clusters

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(df.drop('Class', axis=1))

plt.figure(figsize=(10, 6))
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=df['Class'], palette=['blue', 'red'], alpha=0.6)
plt.title("PCA: Fraud vs Non-Fraud Transactions")
plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.show()

# %%
df.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Class',
#        'Amount_scaled', 'Time_scaled'],
#       dtype='object')

# %%
features = ['V1', 'V2', 'V3', 'V4', 'V5','V6', 'V7', 'V8', 'V9', 'V10' ,'Amount_scaled', 'Time_scaled']
for feature in features:
    sns.kdeplot(df[feature][df.Class == 0], label='Non-Fraud')
    sns.kdeplot(df[feature][df.Class == 1], label='Fraud')
    plt.title(f'Distribution of {feature} by Class')
    plt.legend()
    plt.show()

# %%
X = df.drop('Class', axis=1)
y = df['Class']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
#Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[56851    13]
#  [   35    63]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.83      0.64      0.72        98
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.82      0.86     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
#Trains a Decision Tree ,Makes predictions, Evaluates performance with accuracy, confusion matrix, and classification report

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt

# Train Decision Tree model
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)

# Predict
y_pred_dt = dt_model.predict(X_test)

# Evaluate
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_dt))
print("\nClassification Report:\n", classification_report(y_test, y_pred_dt))
print("Accuracy Score:", accuracy_score(y_test, y_pred_dt))

# Optional: Plot first 2 levels of the tree
plt.figure(figsize=(20,10))
plot_tree(dt_model, max_depth=2, feature_names=X_train.columns, class_names=["Non-Fraud", "Fraud"], filled=True)
plt.title("Decision Tree (First 2 Levels)")
plt.show()
# Out:
# Confusion Matrix:
#  [[56837    27]
#  [   25    73]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.73      0.74      0.74        98
#
#     accuracy                           1.00     56962
#    macro avg       0.86      0.87      0.87     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Accuracy Score: 0.9990871107053826

# %%
#to train a Random Forest, make predictions, and evaluate the model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# Train Random Forest model and evaluate
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)

print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_rf))
print("\nClassification Report:\n", classification_report(y_test, y_pred_rf))
print("Accuracy Score:", accuracy_score(y_test, y_pred_rf))
# Out:
# Confusion Matrix:
#  [[56859     5]
#  [   18    80]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.94      0.82      0.87        98
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.91      0.94     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Accuracy Score: 0.9995962220427653

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Get feature importances
importances = rf_model.feature_importances_
feature_names = X_train.columns

# Create a DataFrame for plotting
feat_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
feat_importance_df = feat_importance_df.sort_values(by='Importance', ascending=False)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feat_importance_df.head(15))  # Top 15 features
plt.title('Top 15 Feature Importances from Random Forest')
plt.tight_layout()
plt.show()

# %%
#to train and evaluate an XGBoost model

# %%
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# Train XGBoost model and evaluate
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
xgb_model.fit(X_train, y_train)
y_pred_xgb = xgb_model.predict(X_test)

print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_xgb))
print("\nClassification Report:\n", classification_report(y_test, y_pred_xgb))
print("Accuracy Score:", accuracy_score(y_test, y_pred_xgb))
# Out:
# C:\Users\M.KAMRAN\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:183: UserWarning: [16:47:45] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Confusion Matrix:
#  [[56852    12]
#  [   20    78]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.87      0.80      0.83        98
#
#     accuracy                           1.00     56962
#    macro avg       0.93      0.90      0.91     56962
# weighted avg       1.00      1.00      1.00     56962
#
# Accuracy Score: 0.9994382219725431

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt

plot_importance(xgb_model, max_num_features=15, importance_type='gain')  # Top 15 features by gain
plt.title('Top 15 Feature Importances from XGBoost')
plt.tight_layout()
plt.show()

# %%
#Applying lightgbm
